# %%
pip install "scikit-learn==1.6.1"
# Out:
# ...
#   Obtaining dependency information for scikit-learn==1.6.1 from https://files.pythonhosted.org/packages/62/27/585859e72e117fe861c2079bcba35591a84f801e21bc1ab85bce6ce60305/scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.1 MB 1.6 MB/s eta 0:00:07
#     --------------------------------------- 0.2/11.1 MB 2.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/11.1 MB 3.7 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/11.1 MB 4.2 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/11.1 MB 4.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/11.1 MB 4.9 MB/s eta 0:00:02
#    ------ --------------------------------- 1.7/11.1 MB 5.3 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/11.1 MB 5.5 MB/s eta 0:00:02
# ...

# %%
import torch

ckpt = torch.load("models/convnextv2_tiny_best.pt", map_location="cpu")

print("num_classes (metadata):", ckpt.get("num_classes"))
cn = ckpt.get("class_names")
print("jumlah class_names     :", len(cn) if cn is not None else None)
print("name / arch            :", ckpt.get("name"))
print("best_f1                :", ckpt.get("best_f1"))

sd = ckpt["model_state"]
print("\nJUMLAH KEY di model_state:", len(sd))

print("\n15 KEY TERAKHIR (head biasanya di sini):")
for k in list(sd.keys())[-15:]:
    print(" ", k, tuple(sd[k].shape))
# Out:
# num_classes (metadata): 53
# jumlah class_names     : 53
# name / arch            : ConvNeXtV2-Tiny
# best_f1                : 0.9451505213434803
#
# JUMLAH KEY di model_state: 200
#
# 15 KEY TERAKHIR (head biasanya di sini):
#   stages.3.blocks.1.mlp.fc2.bias (768,)
#   stages.3.blocks.2.conv_dw.weight (768, 1, 7, 7)
#   stages.3.blocks.2.conv_dw.bias (768,)
#   stages.3.blocks.2.norm.weight (768,)
#   stages.3.blocks.2.norm.bias (768,)
#   stages.3.blocks.2.mlp.fc1.weight (3072, 768)
#   stages.3.blocks.2.mlp.fc1.bias (3072,)
#   stages.3.blocks.2.mlp.grn.weight (3072,)
#   stages.3.blocks.2.mlp.grn.bias (3072,)
#   stages.3.blocks.2.mlp.fc2.weight (768, 3072)
#   stages.3.blocks.2.mlp.fc2.bias (768,)
#   head.norm.weight (768,)
#   head.norm.bias (768,)
#   head.fc.weight (53, 768)
#   head.fc.bias (53,)

# %%
import traceback, joblib, sklearn, numpy, scipy
print("sklearn:", sklearn.__version__)
print("numpy  :", numpy.__version__)
print("scipy  :", scipy.__version__)

try:
    obj = joblib.load("models/malnutrition_model.joblib")
    print("OK, type:", type(obj))
    print(obj)
except Exception:
    traceback.print_exc()
# Out:
# sklearn: 1.9.0
# numpy  : 2.4.4
# scipy  : 1.17.1
# OK, type: <class 'dict'>
# {'model': Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=0.9, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=True, eval_metric='mlogloss',
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
# ...

# %%
py -3.12 -m venv .venv
.\.venv\Scripts\activate
python -m pip install --upgrade pip
pip install "scikit-learn==1.6.1" streamlit torch torchvision timm joblib xgboost pandas numpy plotly pillow
# Out:
#   Cell In[4], line 1
#     py -3.12 -m venv .venv
#                 ^
# SyntaxError: invalid syntax
